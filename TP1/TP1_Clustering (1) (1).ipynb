# %% [markdown]
# # TP: Machine Learning (SIA_3611)
#
# ## TP3: Clustering (4h)
#
# In machine learning, clustering is related to unsupervised learning approaches in which the algorithm fits from the distribution of given data. The main advantage of such methods is detection without a priori of patterns, sorting data and detecting outliers.
#
# The given dataset is a combination of a dataset produced by the World Health Organization and the location of countries. It pooled the evolution of 23 features for 15 years among numerous countries. One of the goals of this TP3 is to detect continents and subcontinents.
#
# **Objectives:**
# - Visualize spatial datasets
# - Apply K-Means and GMM on spatial datasets
# - Normalize the datasets
# - Propose a methodology to detect specific pools of data
# - Evaluate the computed clustering

# %% [markdown]
# ## STEP 1: Spatial datasets and first clusters

# %% [markdown]
# The first step is visualizing the mercator projection.

# %% [markdown]
# **TO DO 1.1**
#
# Execute the following cells

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors

df = pd.read_csv("data/Life_Expectancy_Data.csv")
df = df.dropna()
df.info()

df1 = df[(df.Year == 2013)]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1649 entries, 0 to 2937
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          1649 non-null   object
#  1   Longitude                        1649 non-null   float64
#  2   Latitude                         1649 non-null   float64
#  3   Continent                        1649 non-null   object
#  4   Year                             1649 non-null   int64
#  5   Status                           1649 non-null   object
#  6   Life_expectancy                  1649 non-null   float64
#  7   Adult_mortality                  1649 non-null   float64
#  8   Infant_deaths                    1649 non-null   int64
#  9   Alcohol                          1649 non-null   float64
#  10  Percentage_expenditure           1649 non-null   float64
#  11  Hepatitis_B                      1649 non-null   float64
#  12  Measles                          1649 non-null   int64
#  13  BMI                              1649 non-null   float64
#  14  Under-five_deaths                1649 non-null   int64
#  15  Polio                            1649 non-null   float64
#  16  Total_expenditure                1649 non-null   float64
#  17  Diphtheria                       1649 non-null   float64
#  18  HIV_AIDS                         1649 non-null   float64
#  19  GDP                              1649 non-null   float64
#  20  Population                       1649 non-null   float64
#  21  Thinness _1-19_years             1649 non-null   float64
#  22  Thinness_5-9_years               1649 non-null   float64
#  23  Income_composition_of_resources  1649 non-null   float64
#  24  Schooling                        1649 non-null   float64
# dtypes: float64(18), int64(4), object(3)
# memory usage: 335.0+ KB

# %%
df_X = df1[['Longitude', 'Latitude']]
df_Status = df1[['Continent']]

df_Y = df_Status.replace(['Africa', 'Asia', 'Europe', 'North America', 'South America', 'Seven seas', 'Oceania'], [0, 1, 2, 3, 4, 5, 6])
np_Y = df_Y.to_numpy()
np_Y = np_Y.reshape((np_Y.shape[0],))

np1 = df_X.to_numpy()
plt.scatter(np1[:,0], np1[:,1], c=np_Y, cmap=matplotlib.colors.ListedColormap(['red', 'green', 'blue', 'purple', 'yellow', 'magenta', 'cyan']))
plt
# Out:
# /var/folders/2y/fbjmy99x4_n615508kq38_740000gn/T/ipykernel_4585/1368743086.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_Y = df_Status.replace(['Africa', 'Asia', 'Europe', 'North America', 'South America', 'Seven seas', 'Oceania'], [0, 1, 2, 3, 4, 5, 6])
# <module 'matplotlib.pyplot' from '/Users/jeenyuhs/Desktop/ENSEA/Machine_Learning/TP/venv/lib/python3.13/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# **QUESTION 1**
#
# Identify each class with the plot colors.
#
# What do the coordinates correspond to?

# %% [markdown]
# Each color represents a continent,following the order:
# red is Africa,
# green is Asia,
# blue is Europe,
# purple is North America,
# yellow is south America,
# magenta is Seven,
# cyian is Oceania
#
# The X-axis correspond to longitude and the Y-axis correspond to latitude

# %% [markdown]
# **TO DO 1.2**
#
# Execute the following cell

# %%
from itertools import product
from sklearn import cluster

x_min, x_max = np1[:, 0].min() - 10, np1[:, 0].max() + 10
y_min, y_max = np1[:, 1].min() - 10, np1[:, 1].max() + 10
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

km2 = cluster.KMeans(n_clusters=2).fit(np1)
km3 = cluster.KMeans(n_clusters=3).fit(np1)
km4 = cluster.KMeans(n_clusters=4).fit(np1)
km6 = cluster.KMeans(n_clusters=6).fit(np1)

f, axarr = plt.subplots(2, 2, sharex='col', sharey='row', figsize=(10, 8))

for idx, km, tt in zip(product([0, 1], [0, 1]),
                        [km2, km3, km4, km6],
                        ["K=2, J=%.2f" % km2.inertia_,
                         "K=3, J=%.2f" % km3.inertia_, 
                         "K=4, J=%.2f" % km4.inertia_, 
                         "K=6, J=%.2f" % km6.inertia_]):

    Z = km.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    axarr[idx[0], idx[1]].contourf(xx, yy, Z, alpha=0.4)
    axarr[idx[0], idx[1]].scatter(np1[:, 0], np1[:, 1], c=np_Y,
                                  s=20, cmap=matplotlib.colors.ListedColormap(['red', 'green', 'blue', 'purple', 'yellow', 'magenta', 'cyan']))
    axarr[idx[0], idx[1]].set_title(tt)

plt
# Out:
# <module 'matplotlib.pyplot' from '/Users/jeenyuhs/Desktop/ENSEA/Machine_Learning/TP/venv/lib/python3.13/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# **QUESTION 2**
#
# How can Inertia be used to compare clusters? Can you propose a better metric for spatial datasets?
#
# Which is the main problem with the mercator representation for continent detection?

# %% [markdown]
# Inertia measures the sum of squared distances between each point, it uses compactness, but here we have longtitude and latitude, so it is better to use silhouette score with a spatial dataset.
# The mercator projection distorts areas and distances, which is a problem for detecting continent correctly.

# %% [markdown]
# ## STEP 2: Spatial dataset normalization

# %% [markdown]
# **TO CODE 2.1**
#
# Displace the origin of longitude to 30° east.

# %%
df_X = df1[['Longitude', 'Latitude']]
df_X['Longitude'] = (df_X['Longitude'] - 30 - 180) % 360 - 180



df_Status = df1[['Continent']]

df_Y = df_Status.replace(['Africa', 'Asia', 'Europe', 'North America', 'South America', 'Seven seas', 'Oceania'], [0, 1, 2, 3, 4, 5, 6])
np_Y = df_Y.to_numpy()
np_Y = np_Y.reshape((np_Y.shape[0],))

np1 = df_X.to_numpy()
plt.scatter((np1[:,0]), np1[:,1], c=np_Y, cmap=matplotlib.colors.ListedColormap(['red', 'green', 'blue', 'purple', 'yellow', 'magenta', 'cyan']))
plt
# Out:
# /var/folders/2y/fbjmy99x4_n615508kq38_740000gn/T/ipykernel_4585/554968510.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_X['Longitude'] = (df_X['Longitude'] - 30 - 180) % 360 - 180
# /var/folders/2y/fbjmy99x4_n615508kq38_740000gn/T/ipykernel_4585/554968510.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_Y = df_Status.replace(['Africa', 'Asia', 'Europe', 'North America', 'South America', 'Seven seas', 'Oceania'], [0, 1, 2, 3, 4, 5, 6])
# <module 'matplotlib.pyplot' from '/Users/jeenyuhs/Desktop/ENSEA/Machine_Learning/TP/venv/lib/python3.13/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# **QUESTION 3**
#
# What are the advantages of this normalization?

# %% [markdown]
# Deplacing the origin oft longtitude to 30° East, make the Oceania in a single block, with is better for clustering.

# %% [markdown]
# **TO CODE 2.2**
#
# Apply KMeans to the new normalized dataset.

# %%
from itertools import product
from sklearn import cluster

x_min, x_max = np1[:, 0].min() - 10, np1[:, 0].max() + 10
y_min, y_max = np1[:, 1].min() - 10, np1[:, 1].max() + 10
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

km2 = cluster.KMeans(n_clusters=2).fit(np1)
km3 = cluster.KMeans(n_clusters=3).fit(np1)
km4 = cluster.KMeans(n_clusters=4).fit(np1)
km6 = cluster.KMeans(n_clusters=6).fit(np1)

f, axarr = plt.subplots(2, 2, sharex='col', sharey='row', figsize=(10, 8))

for idx, km, tt in zip(product([0, 1], [0, 1]),
                        [km2, km3, km4, km6],
                        ["K=2, J=%.2f" % km2.inertia_,
                         "K=3, J=%.2f" % km3.inertia_, 
                         "K=4, J=%.2f" % km4.inertia_, 
                         "K=6, J=%.2f" % km6.inertia_]):

    Z = km.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    axarr[idx[0], idx[1]].contourf(xx, yy, Z, alpha=0.4)
    axarr[idx[0], idx[1]].scatter(np1[:, 0], np1[:, 1], c=np_Y,
                                  s=20, cmap=matplotlib.colors.ListedColormap(['red', 'green', 'blue', 'purple', 'yellow', 'magenta', 'cyan']))
    axarr[idx[0], idx[1]].set_title(tt)

# %% [markdown]
# Gaussian Mixture Model is a clustering method allowing soft boundaries.
#
# This method can be used through a [sklearn function](https://scikit-learn.org/stable/modules/generated/sklearn.mixture.GaussianMixture.html "Gaussian Mixture")

# %% [markdown]
# **TO CODE 2.3**
#
# Apply GMM to the normalized dataset.
#
# You have to test 3 conditions:
#
# - GMM with default parameters for 2, 3, 4 and 6 components
#
# - GMM with diagonal covariance matrix for 2, 3, 4 and 6 components
#
# - GMM with random initialization for 2, 3, 4 and 6 components

# %%
from itertools import product
from sklearn import mixture

x_min, x_max = np1[:, 0].min() - 10, np1[:, 0].max() + 10
y_min, y_max = np1[:, 1].min() - 10, np1[:, 1].max() + 10
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

g2 = mixture.GaussianMixture(n_components=2).fit(np1)
g3 = mixture.GaussianMixture(n_components=3).fit(np1)
g4 = mixture.GaussianMixture(n_components=4).fit(np1)
g6 = mixture.GaussianMixture(n_components=6).fit(np1)

f, axarr = plt.subplots(2, 2, sharex='col', sharey='row', figsize=(10, 8))

for idx, g in zip(product([0, 1], [0, 1]),[g2, g3, g4, g6]):

    Z = g.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    axarr[idx[0], idx[1]].contourf(xx, yy, Z, alpha=0.4)
    axarr[idx[0], idx[1]].scatter(np1[:, 0], np1[:, 1], c=np_Y,
                                  s=20, cmap=matplotlib.colors.ListedColormap(['red', 'green', 'blue', 'purple', 'yellow', 'magenta', 'cyan']))
    axarr[idx[0], idx[1]].set_title(g)

# %%
from itertools import product
from sklearn import mixture

x_min, x_max = np1[:, 0].min() - 10, np1[:, 0].max() + 10
y_min, y_max = np1[:, 1].min() - 10, np1[:, 1].max() + 10
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

g2 = mixture.GaussianMixture(n_components=2,covariance_type='diag').fit(np1)
g3 = mixture.GaussianMixture(n_components=3,covariance_type='diag').fit(np1)
g4 = mixture.GaussianMixture(n_components=4,covariance_type='diag').fit(np1)
g6 = mixture.GaussianMixture(n_components=6,covariance_type='diag').fit(np1)

f, axarr = plt.subplots(2, 2, sharex='col', sharey='row', figsize=(10, 8))

for idx, g in zip(product([0, 1], [0, 1]),[g2, g3, g4, g6]):

    Z = g.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    axarr[idx[0], idx[1]].contourf(xx, yy, Z, alpha=0.4)
    axarr[idx[0], idx[1]].scatter(np1[:, 0], np1[:, 1], c=np_Y,
                                  s=20, cmap=matplotlib.colors.ListedColormap(['red', 'green', 'blue', 'purple', 'yellow', 'magenta', 'cyan']))
    axarr[idx[0], idx[1]].set_title(g.n_components)

# %%
from itertools import product
from sklearn import mixture

x_min, x_max = np1[:, 0].min() - 10, np1[:, 0].max() + 10
y_min, y_max = np1[:, 1].min() - 10, np1[:, 1].max() + 10
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

g2 = mixture.GaussianMixture(n_components=2,init_params='random').fit(np1)
g3 = mixture.GaussianMixture(n_components=3,init_params='random').fit(np1)
g4 = mixture.GaussianMixture(n_components=4,init_params='random').fit(np1)
g6 = mixture.GaussianMixture(n_components=6,init_params='random').fit(np1)

f, axarr = plt.subplots(2, 2, sharex='col', sharey='row', figsize=(10, 8))

for idx, g in zip(product([0, 1], [0, 1]),[g2, g3, g4, g6]):

    Z = g.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    axarr[idx[0], idx[1]].contourf(xx, yy, Z, alpha=0.4)
    axarr[idx[0], idx[1]].scatter(np1[:, 0], np1[:, 1], c=np_Y,
                                  s=20, cmap=matplotlib.colors.ListedColormap(['red', 'green', 'blue', 'purple', 'yellow', 'magenta', 'cyan']))
    axarr[idx[0], idx[1]].set_title(g.n_components)

# %% [markdown]
# **QUESTION 4**
#
# Which is the best method to detect continents?
#
# For this method, what would be the probability to find a country in the coordinates [-50, -40]? What methodology can you think of to detect unpopulated oceans?

# %% [markdown]
# I think the first method seems to be the best to detect continents

# %%
g6 = mixture.GaussianMixture(n_components=6,init_params='random').fit(np1)

coordinates = np.array([[-50, -40]])

# Calculate the log-probability and convert it to probability
log_prob = g6.score_samples(coordinates)
probability = np.exp(log_prob)

print(f"Probability of finding a country at [-50, -40]: {probability}")
# Out:
# Probability of finding a country at [-50, -40]: [1.86916156e-08]

# %% [markdown]
# **BONUS**
#
# Rather than applying the previous longitudinal normalization in the mercator projected data and applying k-means, we could directly apply k-means on the unit-sphere representing the earth. The cosine similarity thus becomes a more suitable similarity measure than the euclidean distance.
#
# Apply a KMeans with cosine similarity on the sphere instead of the previously tested euclidean distance in the plane.

# %% [markdown]
# ## STEP 3: Detection of caribbean island

# %% [markdown]
# **TO CODE 3.1**
#
# Isolate the North and South American continents.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors

df = pd.read_csv("data/Life_Expectancy_Data.csv")

df.info()

df1 = df[(df.Year == 2013)]

df2 = pd.concat([df1[(df.Continent == 'North America')],df1[(df.Continent == 'South America')]])
caribbean_countries = ['Dominican Republic', 'Haiti', 'Jamaica', 'Trinidad and Tobago','Saint Vincent and the Grenadines','Saint Lucia','Saint Kitts and Nevis','Grenada','Dominica','Cuba','Antigua and Barbuda','Barbados','Bahamas']
df2['Continent'] = np.where(df2['Country'].isin(caribbean_countries), 'Caribbean', df2['Continent'])

df2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Longitude                        2938 non-null   float64
#  2   Latitude                         2938 non-null   float64
#  3   Continent                        2938 non-null   object
#  4   Year                             2938 non-null   int64
#  5   Status                           2938 non-null   object
#  6   Life_expectancy                  2928 non-null   float64
#  7   Adult_mortality                  2928 non-null   float64
#  8   Infant_deaths                    2938 non-null   int64
#  9   Alcohol                          2744 non-null   float64
#  10  Percentage_expenditure           2938 non-null   float64
#  11  Hepatitis_B                      2385 non-null   float64
#  12  Measles                          2938 non-null   int64
#  13  BMI                              2904 non-null   float64
#  14  Under-five_deaths                2938 non-null   int64
#  15  Polio                            2919 non-null   float64
#  16  Total_expenditure                2712 non-null   float64
#  17  Diphtheria                       2919 non-null   float64
#  18  HIV_AIDS                         2938 non-null   float64
#  19  GDP                              2490 non-null   float64
#  20  Population                       2286 non-null   float64
#  21  Thinness _1-19_years             2904 non-null   float64
#  22  Thinness_5-9_years               2904 non-null   float64
#  23  Income_composition_of_resources  2771 non-null   float64
#  24  Schooling                        2775 non-null   float64
# dtypes: float64(18), int64(4), object(3)
# memory usage: 574.0+ KB
# /var/folders/2y/fbjmy99x4_n615508kq38_740000gn/T/ipykernel_4585/2048637778.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = pd.concat([df1[(df.Continent == 'North America')],df1[(df.Continent == 'South America')]])
# /var/folders/2y/fbjmy99x4_n615508kq38_740000gn/T/ipykernel_4585/2048637778.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = pd.concat([df1[(df.Continent == 'North America')],df1[(df.Continent == 'South America')]])
#                                  Country   Longitude   Latitude  \
# 66                   Antigua and Barbuda  -61.794693  17.277500
# 162                              Bahamas  -76.628430  24.290367
# 210                             Barbados  -59.559797  13.181454
# 258                               Belize  -88.710105  17.200275
# 498                               Canada  -75.697000  45.424724
# 627                           Costa Rica  -84.192088   9.976345
# 659                                 Cuba  -79.016054  21.622895
# 769                             Dominica  -61.357726  15.439470
# 772                   Dominican Republic  -70.505689  18.894331
# 820                          El Salvador  -88.871645  13.739437
# 1044                             Grenada  -61.682202  12.117250
# 1060                           Guatemala  -90.364820  15.694037
# 1124                               Haiti  -72.685275  18.935026
# 1140                            Honduras  -86.615166  14.826882
# 1300                             Jamaica  -77.314826  18.156949
# 1685                              Mexico -102.523452  23.947537
# 1863                           Nicaragua  -85.030530  12.847094
# 1961                              Panama  -80.119152   8.517508
# 2167               Saint Kitts and Nevis  -62.687553  17.264599
# 2170                         Saint Lucia  -60.969699  13.894795
# 2186    Saint Vincent and the Grenadines  -61.201297  13.224723
# 2651                 Trinidad and Tobago  -61.265679  10.457334
# 2796            United States of America  -77.036569  38.895103
# 82                             Argentina  -65.179807 -35.381349
# 306     Bolivia (Plurinational State of)  -64.685386 -16.708148
# 354                               Brazil  -53.097831 -10.787777
# 546                                Chile  -71.382562 -37.730710
# 578                             Colombia  -73.081146   3.913834
# 788                              Ecuador  -78.752019  -1.423816
# 1108                              Guyana  -58.982025   4.793780
# 1993                            Paraguay  -58.400137 -23.228239
# 2009                                Peru  -74.382427  -9.152804
# 2475                            Suriname  -55.912346   4.130554
# 2812                             Uruguay  -56.018071 -32.799515
# 2860  Venezuela (Bolivarian Republic of)  -66.181841   7.124224
#
#           Continent  Year      Status  Life_expectancy  Adult_mortality  \
# 66        Caribbean  2013  Developing             76.1            133.0
# 162       Caribbean  2013  Developing             74.8            172.0
# 210       Caribbean  2013  Developing             75.2             11.0
# 258   North America  2013  Developing             69.8             18.0
# 498   North America  2013  Developing             81.8             67.0
# 627   North America  2013  Developing             79.4             96.0
# 659       Caribbean  2013  Developing             78.7             96.0
# 769       Caribbean  2013  Developing              NaN              NaN
# 772       Caribbean  2013  Developing             73.4            157.0
# 820   North America  2013  Developing             73.0            184.0
# 1044      Caribbean  2013  Developing             73.3            144.0
# 1060  North America  2013  Developing             71.4            189.0
# 1124      Caribbean  2013  Developing             62.7            253.0
# 1140  North America  2013  Developing             74.3             15.0
# 1300      Caribbean  2013  Developing             75.6            136.0
# 1685  North America  2013  Developing             76.6             12.0
# 1863  North America  2013  Developing             73.9            157.0
# 1961  North America  2013  Developing             77.5            118.0
# 2167      Caribbean  2013  Developing              NaN              NaN
# 2170      Caribbean  2013  Developing             74.8            141.0
# 2186      Caribbean  2013  Developing             72.7            161.0
# 2651      Caribbean  2013  Developing             71.0            172.0
# 2796  North America  2013   Developed             78.9             16.0
# 82    South America  2013  Developing             76.0            119.0
# 306   South America  2013  Developing             71.0            192.0
# 354   South America  2013  Developing             74.7            146.0
# 546   South America  2013  Developing             81.0             84.0
# 578   South America  2013  Developing             74.4            145.0
# 788   South America  2013  Developing             76.0            121.0
# 1108  South America  2013  Developing             65.9            218.0
# 1993  South America  2013  Developing             73.8            148.0
# 2009  South America  2013  Developing             75.3            125.0
# 2475  South America  2013  Developing             71.2            179.0
# 2812  South America  2013  Developing             76.8            117.0
# 2860  South America  2013  Developing             73.8            159.0
#
#       Infant_deaths  Alcohol  ...  Polio  Total_expenditure  Diphtheria  \
# 66                0     8.58  ...   98.0               5.33        99.0
# 162               0     9.42  ...   97.0               7.50        97.0
# 210               0     8.74  ...   91.0               7.57        91.0
# 258               0     6.56  ...   95.0               5.79        95.0
# 498               2     8.20  ...   91.0               1.67        91.0
# 627               1     3.42  ...   95.0               9.47        95.0
# 659               1     4.18  ...   99.0               9.48        99.0
# 769               0     0.01  ...   96.0               5.58        96.0
# 772               6     5.93  ...   82.0               4.12        83.0
# 820               2     2.42  ...   92.0               6.95        92.0
# 1044              0     8.25  ...   98.0               6.15        97.0
# 1060             11     1.93  ...   84.0               6.30        85.0
# 1124             14     5.68  ...   67.0               8.10        68.0
# 1140              4     3.11  ...   97.0               9.15        97.0
# 1300              1     3.79  ...   86.0               5.91        93.0
# 1685             32     5.23  ...   83.0               6.30        83.0
# 1863              2     3.58  ...   99.0               8.43        98.0
# 1961              1     6.89  ...   81.0               8.90         8.0
# 2167              0     8.54  ...   96.0               6.14        96.0
# 2170              0     9.73  ...   99.0               7.85        99.0
# 2186              0     7.07  ...   97.0               5.21        97.0
# 2651              0     6.71  ...   94.0               5.98        92.0
# 2796             23     8.82  ...   93.0              16.90        94.0
# 82                8     8.28  ...   99.0               4.99        94.0
# 306               8     3.78  ...   95.0               5.96        94.0
# 354              46     7.24  ...   96.0               8.48        97.0
# 546               2     7.20  ...    9.0               7.53        91.0
# 578              11     4.41  ...   91.0               6.84        91.0
# 788               6     3.77  ...   87.0               7.29        87.0
# 1108              0     7.56  ...   98.0               5.10        98.0
# 1993              3     5.03  ...    8.0               1.49        86.0
# 2009              8     5.38  ...   71.0               5.23        88.0
# 2475              0     6.02  ...   86.0               5.96        86.0
# 2812              0     5.82  ...   94.0               8.68        94.0
# 2860              9     6.71  ...   82.0               4.94        82.0
#
#       HIV_AIDS           GDP   Population  Thinness _1-19_years  \
# 66         0.2  12224.864160          NaN                   3.3
# 162        0.1           NaN          NaN                   2.5
# 210        0.1  15472.781400          NaN                   3.8
# 258        0.2   4688.538443     344181.0                   3.4
# 498        0.1  52413.721160   35155451.0                   0.5
# 627        0.1   1569.666310      47641.0                   1.7
# 659        0.1    676.153440          NaN                   3.4
# 769        0.1    722.756650          NaN                   2.7
# 772        0.3    627.555440    1281296.0                   3.3
# 820        0.2   3895.664491     625777.0                   1.6
# 1044       0.1   7955.615985          NaN                   3.8
# 1060       0.4   3452.828934   15596214.0                   1.2
# 1124       0.5     81.265673    1431776.0                   3.9
# 1140       0.4   2136.773950    8657785.0                   2.2
# 1300       0.6     56.144952     285187.0                   1.8
# 1685       0.1   1298.867660  122535969.0                   1.6
# 1863       0.1   1847.198490    5945747.0                   1.8
# 1961       0.1  11685.979830    3838462.0                   1.9
# 2167       0.1           NaN          NaN                   3.7
# 2170       0.1           NaN          NaN                   4.3
# 2186       0.1           NaN          NaN                   3.5
# 2651       0.3   1967.832830    1348248.0                   5.8
# 2796       0.1           NaN          NaN                   0.7
# 82         0.1  12976.636420   42539925.0                   1.0
# 306        0.1           NaN          NaN                   1.2
# 354        0.1  12216.944600    2248632.0                   2.8
# 546        0.1  15941.397220   17462982.0                   0.8
# 578        0.1     83.586300   47342981.0                   2.1
# 788        0.1    674.982900   15661547.0                   1.3
# 1108       0.3   3944.178173      75881.0                   5.5
# 1993       0.2   4479.958580     646574.0                   2.0
# 2009       0.1   6583.116248    3565716.0                   1.1
# 2475       0.4   9484.568980      54254.0                   3.5
# 2812       0.1  16881.256800       3485.0                   1.5
# 2860       0.1           NaN          NaN                   1.6
#
#       Thinness_5-9_years  Income_composition_of_resources  Schooling
# 66                   3.3                            0.781       13.9
# 162                  2.5                            0.790       12.6
# 210                  3.8                            0.792       15.3
# 258                  3.4                            0.706       12.9
# 498                  0.5                            0.909       15.9
# 627                  1.7                            0.762       13.7
# 659                  3.3                            0.773       14.7
# 769                  2.6                            0.721       12.7
# 772                  3.2                            0.709       13.2
# 820                  1.6                            0.675       13.2
# 1044                 3.8                            0.746       15.8
# 1060                 1.2                            0.611       10.7
# 1124                 3.9                            0.483        9.1
# 1140                 2.1                            0.614       11.6
# 1300                 1.7                            0.727       12.8
# 1685                 1.5                            0.753       12.9
# 1863                 1.7                            0.630       11.5
# 1961                 1.9                            0.773       12.9
# 2167                 3.6                            0.749       13.4
# 2170                 4.3                            0.734       13.1
# 2186                 3.4                            0.717       13.3
# 2651                 6.0                            0.773       12.7
# 2796                 0.6                              NaN        NaN
# 82                   0.9                            0.823       17.3
# 306                  1.1                            0.661       13.8
# 354                  2.7                            0.734       14.2
# 546                  0.8                            0.831       15.6
# 578                  1.9                            0.712       13.3
# 788                  1.1                            0.725       13.4
# 1108                 5.3                            0.633       10.3
# 1993                 1.9                            0.679       12.3
# 2009                 1.1                            0.731       13.4
# 2475                 3.5                            0.719       12.7
# 2812                 1.4                            0.788       15.5
# 2860                 1.5                            0.770       14.2
#
# [35 rows x 25 columns]

# %%
df_X = df2[['Longitude', 'Latitude']]
df_Status = df2[['Continent']]

df_Y = df_Status.replace(['North America', 'South America','Caribbean'], [0, 1, 2])
np_Y = df_Y.to_numpy()
np_Y = np_Y.reshape((np_Y.shape[0],))

np1 = df_X.to_numpy()
plt.figure(figsize=(6, 10))
plt.scatter(np1[:,0], np1[:,1], c=np_Y, cmap=matplotlib.colors.ListedColormap(['purple', 'yellow','blue']))
plt
# Out:
# /var/folders/2y/fbjmy99x4_n615508kq38_740000gn/T/ipykernel_4585/363073119.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_Y = df_Status.replace(['North America', 'South America','Caribbean'], [0, 1, 2])
# <module 'matplotlib.pyplot' from '/Users/jeenyuhs/Desktop/ENSEA/Machine_Learning/TP/venv/lib/python3.13/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# **TO CODE 3.2**
#
# Propose a methodology to create a cluster including caribbean independent nations.

# %%
from itertools import product
from sklearn import mixture

x_min, x_max = np1[:, 0].min() - 10, np1[:, 0].max() + 10
y_min, y_max = np1[:, 1].min() - 10, np1[:, 1].max() + 10
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

g2 = mixture.GaussianMixture(n_components=3,init_params='random').fit(np1)
g3 = mixture.GaussianMixture(n_components=4,init_params='random').fit(np1)

f, axarr = plt.subplots(1, 2, sharex='col', sharey='row', figsize=(12, 10))

for g, ax in zip([g2, g3], axarr):
    Z = g.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # Contour plot for the predicted clusters
    ax.contourf(xx, yy, Z, alpha=0.4)

    # Scatter plot of the original data points
    ax.scatter(np1[:, 0], np1[:, 1], c=np_Y,
               s=20, cmap=matplotlib.colors.ListedColormap(['purple', 'red', 'blue']))
    ax.set_title(g.n_components)

# %%
from itertools import product
from sklearn import mixture

x_min, x_max = np1[:, 0].min() - 10, np1[:, 0].max() + 10
y_min, y_max = np1[:, 1].min() - 10, np1[:, 1].max() + 10
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

g2 = mixture.GaussianMixture(n_components=3,init_params='random').fit(np1)
g3 = mixture.GaussianMixture(n_components=4,init_params='random').fit(np1)

f, axarr = plt.subplots(1, 2, sharex='col', sharey='row', figsize=(12, 10))

for g, ax in zip([g2, g3], axarr):
    Z = g.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # Contour plot for the predicted clusters
    ax.contourf(xx, yy, Z, alpha=0.4)

    # Scatter plot of the original data points
    ax.scatter(np1[:, 0], np1[:, 1], c=np_Y,
               s=20, cmap=matplotlib.colors.ListedColormap(['purple', 'red', 'blue']))
    ax.set_title(g.n_components)

# %%
from itertools import product
from sklearn import mixture

x_min, x_max = np1[:, 0].min() - 10, np1[:, 0].max() + 10
y_min, y_max = np1[:, 1].min() - 10, np1[:, 1].max() + 10
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

g2 = mixture.GaussianMixture(n_components=3,init_params='random').fit(np1)
g3 = mixture.GaussianMixture(n_components=4,init_params='random').fit(np1)

f, axarr = plt.subplots(1, 2, sharex='col', sharey='row', figsize=(12, 10))

for g, ax in zip([g2, g3], axarr):
    Z = g.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # Contour plot for the predicted clusters
    ax.contourf(xx, yy, Z, alpha=0.4)

    # Scatter plot of the original data points
    ax.scatter(np1[:, 0], np1[:, 1], c=np_Y,
               s=20, cmap=matplotlib.colors.ListedColormap(['purple', 'red', 'blue']))
    ax.set_title(g.n_components)

# %% [markdown]
# **QUESTION 5**
#
# Which is the outlier of this clustering problem?

# %% [markdown]
# The outlier of this clustering problem is north American countries , because we don' t have a lot of countries so it makes the clustering harder.

# %% [markdown]
# ## STEP 4 : Evaluating a cluster
#
# In this section, we try to evaluate the quality of the different clusters computed.

# %% [markdown]
# **TO DO 4.1**
# Execute the following cells. On the first cell, you can add code to once again displace the longitude by 30° east.

# %%
df_X = df1[['Longitude', 'Latitude']]
df_X['Longitude'] = (df_X['Longitude'] - 30 - 180) % 360 - 180
df_Status = df1[['Continent']]

df_Y = df_Status.replace(['Africa', 'Asia', 'Europe', 'North America', 'South America', 'Seven seas', 'Oceania'], [0, 1, 2, 3, 4, 5, 6])
np_Y = df_Y.to_numpy()
np_Y = np_Y.reshape((np_Y.shape[0],))

np1 = df_X.to_numpy()
plt.scatter(np1[:,0], np1[:,1], c=np_Y, cmap=matplotlib.colors.ListedColormap(['red', 'green', 'blue', 'purple', 'yellow', 'magenta', 'cyan']))
plt.show()
# Out:
# /var/folders/2y/fbjmy99x4_n615508kq38_740000gn/T/ipykernel_4585/1111649665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_X['Longitude'] = (df_X['Longitude'] - 30 - 180) % 360 - 180
# /var/folders/2y/fbjmy99x4_n615508kq38_740000gn/T/ipykernel_4585/1111649665.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_Y = df_Status.replace(['Africa', 'Asia', 'Europe', 'North America', 'South America', 'Seven seas', 'Oceania'], [0, 1, 2, 3, 4, 5, 6])

# %%
x_min, x_max = np1[:, 0].min() - 10, np1[:, 0].max() + 10
y_min, y_max = np1[:, 1].min() - 10, np1[:, 1].max() + 10
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

# %%
from sklearn.metrics import silhouette_samples, silhouette_score

K = 3

fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.set_xlim([-0.1, 1])
ax1.set_ylim([0, len(np1) + (K + 1) * 10])

km = cluster.KMeans(n_clusters=K, random_state=10)
cluster_labels = km.fit_predict(np1)

silhouette_avg = silhouette_score(np1, cluster_labels)
print("For n_clusters =", K, "The average silhouette_score is :", silhouette_avg)
sample_silhouette_values = silhouette_samples(np1, cluster_labels)

y_lower = 10
for i in range(K):
    ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]
    ith_cluster_silhouette_values.sort()
    
    size_cluster_i = ith_cluster_silhouette_values.shape[0]
    y_upper = y_lower + size_cluster_i

    ax1.fill_betweenx(
        np.arange(y_lower, y_upper),
        0,
        ith_cluster_silhouette_values,
        alpha=0.7,
    )

    ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

    y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    Z = km.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    ax2.contourf(xx, yy, Z, alpha=0.4)
    ax2.scatter(np1[:, 0], np1[:, 1], c=np_Y,
                s=20, cmap=matplotlib.colors.ListedColormap(['red', 'green', 'blue', 'purple', 'yellow', 'magenta', 'cyan']))

    # Labeling the clusters
    centers = km.cluster_centers_
    # Draw white circles at cluster centers
    ax2.scatter(
        centers[:, 0],
        centers[:, 1],
        marker="o",
        c="white",
        alpha=1,
        s=200,
        edgecolor="k",
    )

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker="$%d$" % i, alpha=1, s=50, edgecolor="k")

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(
        "Silhouette analysis for KMeans clustering on sample data with n_clusters = %d"
        % K,
        fontsize=14,
        fontweight="bold",
    )

plt.show()
# Out:
# For n_clusters = 3 The average silhouette_score is : 0.5606777583656894

# %% [markdown]
# **TO DO 4.2**
#
# Apply the previous code for different values of K (2,3,4 and 6).

# %%
from sklearn.metrics import silhouette_samples, silhouette_score

for K in [2,3,4,6]:

    fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(12, 5))
    ax1.set_xlim([-0.1, 1])
    ax1.set_ylim([0, len(np1) + (K + 1) * 10])

    km = cluster.KMeans(n_clusters=K, random_state=10)
    cluster_labels = km.fit_predict(np1)

    silhouette_avg = silhouette_score(np1, cluster_labels)
    print("For n_clusters =", K, "The average silhouette_score is :", silhouette_avg)
    sample_silhouette_values = silhouette_samples(np1, cluster_labels)

    y_lower = 10
    for i in range(K):
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]
        ith_cluster_silhouette_values.sort()
        
        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        ax1.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            alpha=0.7,
        )

        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        y_lower = y_upper + 10  # 10 for the 0 samples

        ax1.set_title("The silhouette plot for the various clusters.")
        ax1.set_xlabel("The silhouette coefficient values")
        ax1.set_ylabel("Cluster label")

        # The vertical line for average silhouette score of all the values
        ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

        ax1.set_yticks([])  # Clear the yaxis labels / ticks
        ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

        # 2nd Plot showing the actual clusters formed
        Z = km.predict(np.c_[xx.ravel(), yy.ravel()])
        Z = Z.reshape(xx.shape)

        ax2.contourf(xx, yy, Z, alpha=0.4)
        ax2.scatter(np1[:, 0], np1[:, 1], c=np_Y,
                    s=20, cmap=matplotlib.colors.ListedColormap(['red', 'green', 'blue', 'purple', 'yellow', 'magenta', 'cyan']))

        # Labeling the clusters
        centers = km.cluster_centers_
        # Draw white circles at cluster centers
        ax2.scatter(
            centers[:, 0],
            centers[:, 1],
            marker="o",
            c="white",
            alpha=1,
            s=200,
            edgecolor="k",
        )

        for i, c in enumerate(centers):
            ax2.scatter(c[0], c[1], marker="$%d$" % i, alpha=1, s=50, edgecolor="k")

        ax2.set_title("The visualization of the clustered data.")
        ax2.set_xlabel("Feature space for the 1st feature")
        ax2.set_ylabel("Feature space for the 2nd feature")

        plt.suptitle(
            "Silhouette analysis for KMeans clustering on sample data with n_clusters = %d"
            % K,
            fontsize=14,
            fontweight="bold",
        )

    plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.40388927378047523
# For n_clusters = 3 The average silhouette_score is : 0.5606777583656894
# For n_clusters = 4 The average silhouette_score is : 0.44464926591415543
# For n_clusters = 6 The average silhouette_score is : 0.4880418409926787

# %% [markdown]
# **Question 6**
#
# According to the silhouette score and the silhouette analysis, which is the most relevant value of K ? Justify your response

# %% [markdown]
# K=6 seemts to be the most relevant because even if we have some errors in the clustering, most continents are grouped and clustered

# %% [markdown]
# **BONUS**
#
# Compute the silhouette score and analyze it for different number of components and parameters of Gaussian Mixture.

# %% [markdown]
# **TO CODE 4.3**
#
# Another way to evaluate the quality of the clustering is through the homogeneity. This metric require a ground truth, so it can't be computed for every clustering problem. Luckily, we do have a ground truth here. Compute the [homogeneity score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.homogeneity_score.html "Homogeneity score") for different values of K.

# %%
from sklearn.metrics import silhouette_samples, silhouette_score, homogeneity_score

K_values = [2, 3, 4, 6]
homogeneity_scores = []

for k in K_values:
    km = cluster.KMeans(n_clusters=k, random_state=10)
    cluster_labels = km.fit_predict(np1)
    
    h_score = homogeneity_score(np_Y, cluster_labels)
    homogeneity_scores.append(h_score)
    print(f"K={k}, Homogeneity Score={h_score:.3f}")

# Optional: plot results
plt.figure(figsize=(6,4))
plt.plot(K_values, homogeneity_scores, marker="o", linestyle="--")
plt.title("Homogeneity Score vs Number of Clusters")
plt.xlabel("Number of Clusters (K)")
plt.ylabel("Homogeneity Score")
plt.xticks(K_values)
plt.grid(True)
plt.show()
# Out:
# K=2, Homogeneity Score=0.205
# K=3, Homogeneity Score=0.424
# K=4, Homogeneity Score=0.557
# K=6, Homogeneity Score=0.803

# %% [markdown]
# **Question 7**
#
# According to the homogeneity score, which is the most relevant value of K ?

# %% [markdown]
# K=6 seems to be the most relevant value, because it has the higher homogenity score

# %% [markdown]
# **BONUS**
# Compute the homogeneity score and analyze it for different number of components and parameters of Gaussian Mixture.

# %% [markdown]
# ## BONUS STEP 5: Alcoholism

# %% [markdown]
# This step is entirely optional and combines all the methods you used for this 3 TPs course.
#
# The main goal is to develop a complete methodology to answer general questions.
#
# All questions have to be justified by your homemade methodology and your methodology has also to be justified.
#
# **QUESTION 1**
#
# In the year 2000, which countries are heavily concerned by an Alcohol issue?
#
# **QUESTION 2**
#
# In these countries and in 2000, which are the parameters linked with Alcoholism? How do you explain these links?
#
# **QUESTION 3**
#
# Which is the evolution trend in these countries between 2000 and 2015? Try to separate these different trends.
#
# **QUESTION 4**
#
# By selecting a specific country, can you explain a decrease or an increase through specific policies?
